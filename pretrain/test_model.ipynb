# %%
# !micromamba env list
# Out:
# Running cells with 'carrace38 (Python 3.8.20)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.

# %%
from ultralytics import YOLO

# %%
model = YOLO("pretrain/signboard.pt")
# Out:
# Running cells with 'carrace38 (Python 3.8.20)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
